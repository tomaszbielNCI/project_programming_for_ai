# %%
# Task 1: Downloading & Cleaning
# Person 1 is responsible for fetching data, cleaning it, and saving it to MongoDB

import os
import pandas as pd
from pymongo import MongoClient

# Connect to MongoDB
client = MongoClient("mongodb://localhost:27017/")
db = client["development_analysis"]

# 1. Download Data
def get_energy():
    # TODO: Download energy dataset
    pass

def get_worldbank(code, name):
    # TODO: Download World Bank data
    pass

def get_emissions():
    # TODO: Download CO2 emissions data
    pass

def get_temps():
    # TODO: Download temperature data
    pass

# 2. Save raw data to MongoDB
def save_db(df, name):
    # TODO: Save DataFrame to MongoDB collection
    pass

# 3. Cleaning data
def clean_data(df, name):
    # TODO: Perform cleaning (remove duplicates, handle missing values, filter years)
    pass

# 4. Load, clean, and merge datasets
def prepare_data():
    # TODO: Load raw data from DB, clean, merge, and save as 'combined_clean'
    pass

# Person 1 executes:
# energy_df = get_energy()
# save_db(energy_df, "energy_raw")
# ... repeat for other datasets ...
# prepare_data()

client.close()
